# %% [markdown]
# # notebook for performing exploratory data analysis - after preprocessing datasets
# # feature correlation, rv2 matrix, pca, trajectory pca, mfa, colored pca with categories, imputation, outlier detection with pyod, remving outliers /found patients. etc......

# %%
# Imports

# %% [markdown]
# ## Feature Correlation Analysis

# %% [markdown]
# ## RV2 Matrix

# %% [markdown]
# ## PCA - Timepoint 1 to 5

# %% [markdown]
# ## Trajectory PCA - Timepoint 1 to 3

# %% [markdown]
# ## MFA - Timepoint 1 to 3

# %% [markdown]
# ## PCA plots colored by categories

# %% [markdown]
# ## Imputation - Miceforest and Median

# %% [markdown]
# ## PyOD Outlier Detection - Zryans Approach

# %% [markdown]
# ## Constructing Datasets for Modeling
